# %%
# Importing Libraries
import pandas as pd
import numpy as np
import re
import nltk
from collections import defaultdict
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
 stop_words = set(stopwords.words('english'))

# %%
# Opening the text files
file1 = open('/content/drive/MyDrive/IR ASSIGNMENT DATASET/Greuze1.txt', encoding = 'utf-8')
file_data1 = file1.read()
file_data1 = file_data1.split(" ")
file_data1 = " ".join([re.sub('[^A-Za-z0-9]',' ',i) for i in file_data1])

file2 = open('/content/drive/MyDrive/IR ASSIGNMENT DATASET/Greuze2.txt', encoding = 'utf-8')
file_data2 = file2.read()
file_data2 = file_data2.split(" ")
file_data2 = " ".join([re.sub('[^A-Za-z0-9]',' ',i) for i in file_data2])

file3 = open('/content/drive/MyDrive/IR ASSIGNMENT DATASET/Greuze3.txt', encoding = 'utf-8')
file_data3 = file3.read()
file_data3 = file_data3.split(" ")
file_data3 = " ".join([re.sub('[^A-Za-z0-9]',' ',i) for i in file_data3])

# %%
text_tokens = word_tokenize(file_data1 + " " + file_data2 + " " + file_data3)
filtered_text = [w for w in text_tokens if not w.lower() in stop_words]
 
filtered_text = " ".join(filtered_text)

# %%
filtered_text
# Out:
# 'Project Gutenberg eBook Greuze Harold Armitage eBook use anyone anywhere United States parts world cost almost restrictions whatsoever may copy give away use terms Project Gutenberg License included eBook online www gutenberg org located United States check laws country located using eBook Title Greuze Author Harold Armitage Release Date October 24 2022 eBook 69226 Language English Produced Al Haines START PROJECT GUTENBERG EBOOK GREUZE Frontispiece INNOCENCE Bell Miniature Series Painters GREUZE HAROLD ARMITAGE LONDON GEORGE BELL SONS 1902 v PREFACE Although Paris eighteenth century became home artists subtle genius Greuze yet pictures painter alluring period become familiar people country Engravings etchings photographs reproductions colour works Greuze abound every hand many admired art known much name artist known name still far knowledge story life Indeed though brief narrations Greuze suffered world appeared volumes contained also biographies artists book country devoted solely account romantic career Moreover addition twenty one works Greuze possessions British nation bequest Wallace Collection exhibition nine Art Gallery Corporation London 1902 must awakened curiosity concerning painter whose peculiar place evolution art France vi whose character whose eventful life make history interesting alike delight pictures read biography sake author hopes volume make available hitherto account principal happenings story artist whose charming pictures world many years intimately acquainted vii TABLE CONTENTS Early Years Fame Paris Poverty Death Romance Tragedy Personal Characteristics Characteristics Work Position French Art Illustrations Chief Works Greuze viii LIST ILLUSTRATIONS Innocence Frontispiece Village Bride L Accord e de Village Pretty Laundress La Belle Blanchisseuse Listening Girl Kiss Le Baiser Jet Portrait Robespierre Broken Pitcher La Cruche Cass e Milkmaid La Laiti 1 LIFE GREUZE EARLY YEARS way life Jean Baptiste Greuze spent childhood youth different artists parents obscure people riches father opposed desire painter many years even countrymen wrote Greuze gave date birth time 1725 1732 known accurate date August 21 1725 one since inscribed modest house Tournus near con father mother living artist born time Greuze eight years age manifested strong inclination towards use pencil Drawing became chief amusement employed indifferently stray pieces paper whitewashed walls display draughtsmanship father way fathers planned son position exalted occupation connected elder Greuze 2 kind provincial builder contractor slater wished younger Greuze become architect Although apparent architect day undergoes severe discipline drawing worse propensity sketching yet stated biographers Greuze father used persuasions threats prevent son making drawings boy thereby driven device exercising skill surreptitiously bedroom day came father saw folly continued resistance Mistaking engraving head St James son copied pen might give father birthday present elder Greuze much impressed skill lad thought better allow way choice profession Greuze therefore became pupil Grandon Lyons portrait painter Grandon constitution artist subservient man affairs De Goncourt written studio veritable picture factory Greuze however elevated notions vocation artist remain content marking time rest life sort inglorious piece worker ambition self confidence urged Paris believed powers would win fame fortune 3 Paris Greuze worked unobtrusively often solitude earned precarious livelihood possibly without invoking aid methods master left Lyons immediately successful chance triumphing obstacles beset raw youth provinces seeking fame Paris seemed remote one Yet Pigalle king sculptor believing Greuze qualities win success ultimately encouraged painter persevere Greuze fancied contend hostility jealousy artists Academy went draw received less consideration ability merited complained eventually artist Silvestre also showed specimens work Silvestre admiring skill wished  ...

# %%
# Retrieving unique words from the document
unique_words_list = [set(filtered_text.split(" "))]
unique_words = set().union(*unique_words_list)

# %%
unique_words
# Out:
# {'story',
#  'pleased',
#  'nestles',
#  'fifteen',
#  'furniture',
#  'fame',
#  'introduce',
#  'detach',
#  'spent',
#  'bodily',
#  'formats',
#  'Replacement',
#  'rhetorical',
#  'worldling',
#  'Baiser',
#  'wish',
#  'heedless',
#  'gone',
#  'public',
#  'Defect',
#  'odd',
#  'loitered',
#  'clad',
#  'theatrical',
#  'place',
#  'undisturbed',
#  'viewed',
#  'Tromp',
#  'staunch',
#  'anatomical',
#  'fitting',
#  'appropriate',
#  'etchings',
#  'compelled',
#  'certain',
#  '50',
#  '42',
#  'Papinien',
#  '650',
#  'dirty',
#  'taking',
#  'sky',
#  'pension',
#  'knocking',
#  'intrinsic',
#  'remote',
#  'flowers',
#  'difference',
#  'name',
#  'Rue',
#  'loosed',
#  'CONTRACT',
#  '1',
#  'continued',
#  'ruin',
#  'using',
#  'mixture',
#  'John',
#  'Newton',
#  'fell',
#  'musty',
#  'redeems',
#  'filthiness',
#  'chairs',
#  'Strass',
#  'TABLE',
#  'impressions',
#  'recently',
#  'Leslie',
#  'paragraph',
#  'pedestals',
#  'Dilke',
#  'childish',
#  'EXPRESS',
#  'arise',
#  'opinion',
#  'FULL',
#  'Lagren',
#  'far',
#  'inscribed',
#  'draped',
#  'paid',
#  'respectful',
#  'sober',
#  'gathered',
#  'Manchester',
#  'Exceptionally',
#  'goals',
#  'position',
#  'quitted',
#  'saucepan',
#  'passed',
#  'consulting',
#  'Sir',
#  'white',
#  'lives',
#  'Rois',
#  'painter',
#  'squander',
#  'Renouvier',
#  'distracted',
#  'buckles',
#  'vehemence',
#  'retainer',
#  'length',
#  'attached',
#  'unrestrained',
#  'Gauze',
#  'left',
#  'Stevenson',
#  'chimneys',
#  '45',
#  'listens',
#  'evasive',
#  'prevented',
#  'whose',
#  'notice',
#  'history',
#  'unfinished',
#  '14',
#  'located',
#  'Besan',
#  'incidents',
#  'youngest',
#  'et',
#  'make',
#  'openly',
#  'address',
#  'Lille',
#  'false',
#  'Court',
#  'Marigny',
#  'love',
#  'marked',
#  'Cupids',
#  'daily',
#  'ineffectual',
#  'inevitable',
#  'ART',
#  'backslider',
#  'faubourg',
#  'secretly',
#  'acquired',
#  'convince',
#  'manager',
#  'chamber',
#  'disant',
#  'remove',
#  'livres',
#  'nine',
#  'edition',
#  'discovered',
#  'fortune',
#  'patience',
#  'F',
#  'us',
#  'Nearly',
#  'Many',
#  'becoming',
#  'limited',
#  'eclipsed',
#  'Critical',
#  'lui',
#  'Girl',
#  'methods',
#  'five',
#  'Often',
#  'result',
#  'Head',
#  'split',
#  'work',
#  'date',
#  'bride',
#  'final',
#  'gracious',
#  'typical',
#  'distributing',
#  'sings',
#  'canvases',
#  'POSSIBILITY',
#  'burst',
#  'dealt',
#  'carefully',
#  'Exhibition',
#  'Gaillard',
#  'unpleasant',
#  'remained',
#  'collections',
#  'Email',
#  'Salt',
#  'hopes',
#  'insouciance',
#  'seventeenth',
#  'assumed',
#  'L',
#  'two',
#  'implied',
#  'NATIONAL',
#  'nearly',
#  'became',
#  'stratagem',
#  'sympathy',
#  'permission',
#  'Saint',
#  'Scotland',
#  'worked',
#  'indefatigable',
#  'fascination',
#  'success',
#  '6',
#  'Romance',
#  'criticism',
#  'century',
#  'bonds',
#  'speech',
#  'LIABILITY',
#  'awaited',
#  'ruins',
#  'provided',
#  'void',
#  'EIN',
#  'ami',
#  'world',
#  '30',
#  'swamp',
#  'warmed',
#  'lightly',
#  'replica',
#  'B',
#  'identify',
#  'stirred',
#  'kindness',
#  'action',
#  'serious',
#  'qualities',
#  'irritability',
#  'allow',
#  'chapters',
#  'purchaser',
#  '000',
#  'lovable',
#  'USE',
#  'devoted',
#  'infringement',
#  'temptation',
#  'imperceptible',
#  'letters',
#  'Concerning',
#  'shop',
#  'share',
#  'Mulready',
#  'successful',
#  'spoils',
#  'Infant',
#  'much',
#  'permanent',
#  'seeming',
#  'derived',
#  'exhibited',
#  'Charles',
#  'departs',
#  'drunkards',
#  'restored',
#  'essay',
#  'title',
#  'together',
#  'sir',
#  'Dame',
#  'charge',
#  'tired',
#  'Revenue',
#  'difficulty',
#  'Duchess',
#  'visits',
#  'eyebrows',
#  'Mansion',
#  'old',
#  'banks',
#  'bombastic',
#  'dissimilarity',
#  'boulevards',
#  'sun',
#  'bookseller',
#  'tomb',
#  'friends',
#  'addresses',
#  'introduced',
#  'States',
#  'limelight',
#  'installed',
#  'Palleri',
#  '15',
#  'wonder',
#  'provision',
#  'looks',
#  'Georges',
#  '32',
#  'food',
#  'lessons',
#  'inflated',
#  'PGLAF',
#  'theatre',
#  'differences',
#  'tragedy',
#  'consists',
#  'dignity',
#  'vet',
#  'pretended',
#  'ological',
#  'comely',
#  'impetuous',
#  'powers',
#  'builder',
#  'prices',
#  'knees',
#  'HAROLD',
#  'une',
#  'hear',
#  'least',
#  'figure',
#  'exporting',
#  'Axel',
#  'damaged',
#  'disreputable',
#  'overwhelmed',
#  'provide',
#  'one',
#  'convinces',
#  'water',
#  'Century',
#  'Stone',
#  'Robert',
#  'artists',
#  'palaces',
#  'ROBESPIERRE',
#  'passionately',
#  'faults',
#  'Compi',
#  'N',
#  'rank',
#  'preached',
#  'superintend',
#  'short',
#  'cle',
#  'thinking',
#  'devout',
#  'early',
#  'human',
#  'costly',
#  'tedious',
#  'Cass',
#  'reads',
#  'blow',
#  'factory',
#  'hostility',
#  'corrupt',
#  'softened',
#  'copying',
#  'enabled',
#  'freed',
#  'Section',
#  'cover',
#  'boys',
#  'discuss',
#  'Quarter',
#  'stored',
#  'city',
#  '6221541',
#  'accessed',
#  'earrings',
#  'life',
#  'captivate',
#  'country',
#  'encouraged',
#  'website',
#  'French',
#  'manner',
#  'INDIRECT',
#  'fellow',
#  'go',
#  'errors',
#  'fared',
#  'washing',
#  'defect',
#  '4',
#  'handsome',
#  'destroyed',
#  'magistrates',
#  'opportunity',
#  'barren',
#  'literary',
#  'charming',
#  'confirmation',
#  'taken',
#  'Jet',
#  'individual',
#  '20',
#  'Dijon',
#  'illustrious',
#  'various',
#  'anything',
#  'nineteenth',
#  'vein',
#  'conduct',
#  'Three',
#  'Personal',
#  'mind',
#  'ability',
#  'appeal',
#  'chivalrous',
#  'robe',
#  'merits',
#  'commendation',
#  'UNITED',
#  'Levasseur',
#  'smart',
#  'light',
#  'issued',
#  'p',
#  'carry',
#  'Bell',
#  'minds',
#  'process',
#  'Truly',
#  'wasted',
#  'merit',
#  'princes',
#  'homilies',
#  'feeling',
#  'BREACH',
#  'industry',
#  'affected',
#  'creation',
#  'convert',
#  'apparent',
#  'virus',
#  'dog',
#  'cajoleries',
#  'picturesque',
#  'Apple',
#  'accumulate',
#  'unsolicited',
#  'sometimes',
#  'books',
#  'strayed',
#  'hind',
#  'helped',
#  'fees',
#  'troubled',
#  'seat',
#  'vient',
#  'Strogonoff',
#  '49',
#  'Offrande',
#  'Yarborough',
#  'notifies',
#  'ideals',
#  'research',
#  'official',
#  'stage',
#  '7',
#  'downcast',
#  'Biographie',
#  'Arthur',
#  'reprochant',
#  'hastens',
#  'Nantes',
#  'degenerated',
#  'month',
#  'employment',
#  'attach',
#  'kiss',
#  'achieved',
#  'palace',
#  'give',
#  'shed',
#  'reaped',
#  'downright',
#  'fear',
#  'invoking',
#  'exercising',
#  'witness',
#  'ought',
#  'talk',
#  'shoulders',
#  'widest',
#  'Language',
#  'say',
#  'candour',
#  'times',
#  'classes',
#  'giving',
#  'blurted',
#  'ascertained',
#  'burning',
#  'inasmuch',
#  'alone',
#  'pearly',
#  'man',
#  'school',
#  'August',
#  'Mistaking',
#  'impressive',
#  'main',
#  'gin',
#  'congratulate',
#  'ever',
#  'delirium',
#  'imperfection',
#  'letter',
#  'farm',
#  'description',
#  'yoke',
#  'rooms',
#  'god',
#  'c',
#  'confidence',
#  'advanced',
#  'states',
#  'walking',
#  'injustices',
#  'novelty',
#  'face',
#  'wedding',
#  'freak',
#  'introduction',
#  'Laundress',
#  'servants',
#  'suggesting',
#  'il',
#  'Also',
#  'real',
#  'precarious',
#  'sentimental',
#  'tops',
#  'quays',
#  'processes',
#  'proofread',
#  'Fille',
#  'pitcher',
#  'crossing',
#  'modern',
#  'housekeeping',
#  'LICENSE',
#  'cause',
#  'perfidious',
#  'distinction',
#  'explanation',
#  'died',
#  'Mission',
#  'represented',
#  'considered',
#  'bookshop',
#  'risk',
#  'heart',
#  'hope',
#  'perhaps',
#  'sublimation',
#  'Marseille',
#  'ceased',
#  'copied',
#  'dans',
#  'One',
#  'reports',
#  '13',
#  'verge',
#  'yet',
#  'cemetery',
#  'dish',
#  'Sections',
#  'gain',
#  'apart',
#  'demurrer',
#  'Arcade',
#  'doors',
#  'cried',
#  'agreement',
#  'commencing',
#  'remarkable',
#  '1874',
#  'provincial',
#  'refinements',
#  'playing',
#  'Works',
#  'chamberlain',
#  'resplendent',
#  'come',
#  'God',
#  'charms',
#  'forest',
#  'hundreds',
#  'laid',
#  'poor',
#  'dashing',
#  'wishes',
#  'touching',
#  'ten',
#  'broke',
#  'comprehensive',
#  'Une',
#  'dawn',
#  'INCLUDING',
#  'last',
#  'coup',
#  'redistributing',
#  'vengeance',
#  'CONSEQUENTIAL',
#  'present',
#  'reaching',
#  'study',
#  'needed',
#  'illustration',
#  'whole',
#  'extraordinary',
#  'morals',
#  'maticien',
#  'lieu',
#  'artificial',
#  'bread',
#  'copy',
#  'sunk',
#  'page',
#  'Homme',
#  'social',
#  'treasured',
#  'enough',
#  'License',
#  'indicated',
#  'cease',
#  'circle',
#  'later',
#  'Savoy',
#  'mistaking',
#  'Barthelemy',
#  'song',
#  'proprietary',
#  'feels',
#  'ROMANCE',
#  'occupies',
#  'bourgeois',
#  'beset',
#  'washerwomen',
#  'sits',
#  'host',
#  'splendour',
#  '1732',
#  'rosy',
#  'C',
#  'Napoleon',
#  'Terms',
#  'end',
#  'delicious',
#  'closed',
#  'teach',
#  'clear',
#  'waistcoat',
#  'round',
#  'Lesser',
#  'Artistes',
#  'classicism',
#  'Peintres',
#  'approach',
#  'longer',
#  'winsome',
#  'Whistler',
#  'verdigris',
#  'dreary',
#  'hitherto',
#  'ease',
#  'surprised',
#  'ran',
#  'warranties',
#  'completed',
#  'twenty',
#  'posy',
#  'skill',
#  'parle',
#  'linked',
#  'FRANCE',
#  'James',
#  'wife',
#  '56',
#  'Service',
#  'Mariage',
#  'plates',
#  'Tendre',
#  'pretty',
#  'Cook',
#  'solitude',
#  'BESAN',
#  'therefore',
#  'refuse',
#  'kept',
#  'v',
#  'thick',
#  'injustice',
#  'treated',
#  'Rousseau',
#  'Boucher',
#  'charitable',
#  'heed',
#  'International',
#  'Duc',
#  'LAUNDRESS',
#  'merited',
#  'studio',
#  'satisfaction',
#  'DISTRIBUTOR',
#  'Draped',
#  'Donaldson',
#  'smote',
#  'COLLECTION',
#  'sublime',
#  'pleure',
#  'Whose',
#  'academic',
#  'standards',
#  'native',
#  'Brown',
#  'clearly',
#  'communicate',
#  'sympathetic',
#  'reaction',
#  'armour',
#  'obtrusive',
#  '34',
#  'heap',
#  'gloomy',
#  'went',
#  'clock',
#  'intense',
#  'animated',
#  'bores',
#  'precisely',
#  'step',
#  'evidence',
#  'eldest',
#  'beautifully',
#  'certainty',
#  'exclaimed',
#  'recent',
#  'stormers',
#  'preacher',
#  'attributed',
#  'within',
#  'crime',
#  'seeing',
#  'gave',
#  'rouge',
#  'forehead',
#  'Fontainebleau',
#  'Este',
#  'loving',
#  'appearing',
#  'exclusion',
#  'peculiarly',
#  'version',
#  'exhibit',
#  'generally',
#  'foolish',
#  'PUNITIVE',
#  '596',
#  'Zola',
#  'PERSONAL',
#  'houses',
#  'fourteen',
#  'prominently',
#  'assume',
#  'push',
#  'paper',
#  '1885',
#  'Alexander',
#  'se',
#  'teaching',
#  'ses',
#  'effective',
#  'Almost',
#  'began',
#  'Jointes',
#  'unsatisfactory',
#  'speaks',
#  'Lowther',
#  '90',
#  'particular',
#  'reveal',
#  'instability',
#  'demonstrated',
#  'sisters',
#  'returned',
#  'barbaric',
#  'attention',
#  'utter',
#  'day',
#  'colours',
#  'Jar',
#  'house',
#  'Mal',
#  'seventy',
#  'sweet',
#  'Poverty',
#  'reward',
#  'Marquis',
#  'perished',
#  'answered',
#  'PG',
#  'rules',
#  'Live',
#  'pleasantries',
#  'Maclise',
#  'array',
#  'stools',
#  'wash',
#  'fee',
#  'viii',
#  'uniform',
#  'Martin',
#  '1821',
#  'mother',
#  'pictorial',
#  'suspicion',
#  'House',
#  'departure',
#  'brusque',
#  'breaking',
#  'complete',
#  'market',
#  'Troyes',
#  'meadow',
#  'Lake',
#  'motive',
#  'lit',
#  'hour',
#  'compensated',
#  'purpose',
#  'Donations',
#  'following',
#  'dust',
#  'GUILDFORD',
#  'conventions',
#  'advocate',
#  'loose',
#  'part',
#  'fancy',
#  'three',
#  'presentment',
#  'death',
#  'distributed',
#  'willingness',
#  'another',
#  'amidst',
#  'hide',
#  'RIGHT',
#  'journals',
#  'epoch',
#  'finished',
#  'journalist',
#  'filled',
#  'persuasions',
#  'primarily',
#  'dainty',
#  'computer',
#  '1895',
#  'stretches',
#  'Robespierre',
#  'esteem',
#  'amenity',
#  'thousand',
#  'well',
#  'accord',
#  'demeanour',
#  'door',
#  'draws',
#  'virtue',
#  'bodices',
#  'away',
#  'described',
#  'Engravings',
#  'directly',
#  'abuse',
#  'adopted',
#  'rested',
#  'danger',
#  'keeping',
#  'vain',
#  'deliberate',
#  'constitution',
#  '11',
#  'neglect',
#  '43',
#  'finds',
#  'connoisseur',
#  'obscure',
#  'sold',
#  'bourgeoise',
#  'Solomon',
#  'Hundreds',
#  'Anne',
#  'Twelve',
#  'principal',
#  'pastorals',
#  'already',
#  'genius',
#  'maledictions',
#  'indicates',
#  'dilettanti',
#  'fresh',
#  'R',
#  'says',
#  'profoundly',
#  'men',
#  'Mains',
#  'gauze',
#  'authority',
#  'www',
#  'domestic',
#  '27',
#  'sister',
#  'Thirty',
#  'pleasure',
#  'excellence',
#  'harmless',
#  'knew',
#  'livelihood',
#  'charm',
#  'easel',
#  'absolutely',
#  'await',
#  'quelle',
#  'pointillists',
#  'lower',
#  'Kiss',
#  'second',
#  'historique',
#  'computers',
#  'indeed',
#  'providing',
#  'attracted',
#  'Duke',
#  'stammer',
#  'employees',
#  'production',
#  'arched',
#  'somewhat',
#  'belong',
#  'relate',
#  'engraved',
#  'agree',
#  'strong',
#  'asked',
#  'absurdities',
#  'enthusiastic',
#  'ideas',
#  'directed',
#  'fall',
#  'Barth',
#  'Like',
#  'simplicity',
#  'often',
#  'slow',
#  'bridegroom',
#  'toys',
#  'request',
#  'labour',
#  'recognise',
#  'based',
#  'Fabricius',
#  'tints',
#  'shirt',
#  'Ducreux',
#  'sketch',
#  'Reginald',
#  'hung',
#  'strain',
#  'obtaining',
#  'Muther',
#  'father',
#  'phrase',
#  'believe',
#  'voluptuousness',
#  'Eighteenth',
#  'sent',
#  'Nothing',
#  'keep',
#  'duties',
#  'forced',
#  'threats',
#  'change',
#  'excellent',
#  'like',
#  'profits',
#  'steps',
#  'De',
#  'searching',
#  'measure',
#  'Servi',
#  'Carlyle',
#  'Bible',
#  'promised',
#  'moved',
#  'member',
#  ...}

# %%
# Defining a dictionary which has the unique words as keys and the document number as values
# The document number is from 1 to 3.
document = defaultdict(list)
for word  in unique_words:
  if word != " " or word != '':
    if word in file_data1.split(" "):
      document[word].append('1')
    else:
      pass
    if word in file_data2.split(" "):
      document[word].append('2')
    else:
      pass
    if word in file_data3.split(" "):
      document[word].append('3')
  else:
    continue

# %%
document
# Out:
# defaultdict(list,
#             {'story': ['1', '2', '3'],
#              'pleased': ['2'],
#              'nestles': ['2'],
#              'fifteen': ['3'],
#              'furniture': ['3'],
#              'fame': ['1', '3'],
#              'introduce': ['3'],
#              'detach': ['3'],
#              'spent': ['1'],
#              'bodily': ['2'],
#              'formats': ['3'],
#              'Replacement': ['3'],
#              'rhetorical': ['3'],
#              'worldling': ['3'],
#              'Baiser': ['1', '3'],
#              'wish': ['1', '3'],
#              'heedless': ['1'],
#              'gone': ['1', '2'],
#              'public': ['1', '2', '3'],
#              'Defect': ['3'],
#              'odd': ['2'],
#              'loitered': ['1'],
#              'clad': ['3'],
#              'theatrical': ['2'],
#              'place': ['1', '2', '3'],
#              'undisturbed': ['2'],
#              'viewed': ['3'],
#              'Tromp': ['1'],
#              'staunch': ['1'],
#              'anatomical': ['2'],
#              'fitting': ['1'],
#              'appropriate': ['2'],
#              'etchings': ['1'],
#              'compelled': ['2'],
#              'certain': ['2', '3'],
#              '50': ['3'],
#              '42': ['2'],
#              'Papinien': ['1'],
#              '650': ['3'],
#              'dirty': ['2'],
#              'taking': ['1', '2', '3'],
#              'sky': ['2'],
#              'pension': ['1'],
#              'knocking': ['2'],
#              'intrinsic': ['2'],
#              'remote': ['1'],
#              'flowers': ['1', '2', '3'],
#              'difference': ['2', '3'],
#              'name': ['1', '3'],
#              'Rue': ['1'],
#              'loosed': ['3'],
#              'CONTRACT': ['3'],
#              '1': ['1', '3'],
#              'continued': ['1', '2'],
#              'ruin': ['2'],
#              'using': ['1', '3'],
#              'mixture': ['2'],
#              'John': ['2', '3'],
#              'Newton': ['3'],
#              'fell': ['1'],
#              'musty': ['3'],
#              'redeems': ['2'],
#              'filthiness': ['3'],
#              'chairs': ['3'],
#              'Strass': ['2'],
#              'TABLE': ['1'],
#              'impressions': ['1'],
#              'recently': ['1', '3'],
#              'Leslie': ['3'],
#              'paragraph': ['3'],
#              'pedestals': ['3'],
#              'Dilke': ['2', '3'],
#              'childish': ['2'],
#              'EXPRESS': ['3'],
#              'arise': ['3'],
#              'opinion': ['1'],
#              'FULL': ['3'],
#              'Lagren': ['1'],
#              'far': ['1', '2', '3'],
#              'inscribed': ['1'],
#              'draped': ['2', '3'],
#              'paid': ['1', '2', '3'],
#              'respectful': ['2', '3'],
#              'sober': ['3'],
#              'gathered': ['1'],
#              'Manchester': ['2'],
#              'Exceptionally': ['1'],
#              'goals': ['3'],
#              'position': ['1', '2', '3'],
#              'quitted': ['1'],
#              'saucepan': ['2'],
#              'passed': ['1', '2', '3'],
#              'consulting': ['1'],
#              'Sir': ['2', '3'],
#              'white': ['2', '3'],
#              'lives': ['3'],
#              'Rois': ['3'],
#              'painter': ['1', '2', '3'],
#              'squander': ['1'],
#              'Renouvier': ['3'],
#              'distracted': ['1'],
#              'buckles': ['3'],
#              'vehemence': ['2'],
#              'retainer': ['1'],
#              'length': ['1'],
#              'attached': ['3'],
#              'unrestrained': ['3'],
#              'Gauze': ['3'],
#              'left': ['1', '3'],
#              'Stevenson': ['2'],
#              'chimneys': ['2'],
#              '45': ['3'],
#              'listens': ['3'],
#              'evasive': ['2'],
#              'prevented': ['1'],
#              'whose': ['1', '2', '3'],
#              'notice': ['1', '2', '3'],
#              'history': ['1', '2'],
#              'unfinished': ['1'],
#              '14': ['1'],
#              'located': ['1', '3'],
#              'Besan': ['2'],
#              'incidents': ['2'],
#              'youngest': ['3'],
#              'et': ['1', '2'],
#              'make': ['1', '2', '3'],
#              'openly': ['1'],
#              'address': ['3'],
#              'Lille': ['3'],
#              'false': ['2', '3'],
#              'Court': ['1', '3'],
#              'Marigny': ['2', '3'],
#              'love': ['1', '2', '3'],
#              'marked': ['1', '3'],
#              'Cupids': ['2'],
#              'daily': ['3'],
#              'ineffectual': ['3'],
#              'inevitable': ['3'],
#              'ART': ['3'],
#              'backslider': ['1'],
#              'faubourg': ['2'],
#              'secretly': ['1', '2'],
#              'acquired': ['1'],
#              'convince': ['1'],
#              'manager': ['3'],
#              'chamber': ['3'],
#              'disant': ['1'],
#              'remove': ['1', '3'],
#              'livres': ['1', '2', '3'],
#              'nine': ['1'],
#              'edition': ['3'],
#              'discovered': ['1', '3'],
#              'fortune': ['1', '2'],
#              'patience': ['1'],
#              'F': ['3'],
#              'us': ['1', '2', '3'],
#              'Nearly': ['3'],
#              'Many': ['1', '2', '3'],
#              'becoming': ['1'],
#              'limited': ['3'],
#              'eclipsed': ['1'],
#              'Critical': ['3'],
#              'lui': ['1'],
#              'Girl': ['1', '2', '3'],
#              'methods': ['1', '3'],
#              'five': ['1', '2', '3'],
#              'Often': ['2'],
#              'result': ['2'],
#              'Head': ['2', '3'],
#              'split': ['2'],
#              'work': ['1', '2', '3'],
#              'date': ['1', '3'],
#              'bride': ['3'],
#              'final': ['3'],
#              'gracious': ['2'],
#              'typical': ['2'],
#              'distributing': ['3'],
#              'sings': ['2'],
#              'canvases': ['1', '2'],
#              'POSSIBILITY': ['3'],
#              'burst': ['1'],
#              'dealt': ['2'],
#              'carefully': ['1'],
#              'Exhibition': ['2'],
#              'Gaillard': ['1'],
#              'unpleasant': ['3'],
#              'remained': ['1'],
#              'collections': ['2', '3'],
#              'Email': ['3'],
#              'Salt': ['3'],
#              'hopes': ['1'],
#              'insouciance': ['2'],
#              'seventeenth': ['3'],
#              'assumed': ['1'],
#              'L': ['1', '2', '3'],
#              'two': ['1', '2', '3'],
#              'implied': ['2', '3'],
#              'NATIONAL': ['3'],
#              'nearly': ['2', '3'],
#              'became': ['1', '2', '3'],
#              'stratagem': ['2'],
#              'sympathy': ['1'],
#              'permission': ['3'],
#              'Saint': ['1', '2'],
#              'Scotland': ['3'],
#              'worked': ['1'],
#              'indefatigable': ['2'],
#              'fascination': ['3'],
#              'success': ['1', '2'],
#              '6': ['1', '3'],
#              'Romance': ['1'],
#              'criticism': ['1', '2', '3'],
#              'century': ['1', '2', '3'],
#              'bonds': ['3'],
#              'speech': ['3'],
#              'LIABILITY': ['3'],
#              'awaited': ['1'],
#              'ruins': ['3'],
#              'provided': ['3'],
#              'void': ['3'],
#              'EIN': ['3'],
#              'ami': ['1'],
#              'world': ['1', '2', '3'],
#              '30': ['2', '3'],
#              'swamp': ['3'],
#              'warmed': ['2'],
#              'lightly': ['2'],
#              'replica': ['3'],
#              'B': ['3'],
#              'identify': ['3'],
#              'stirred': ['2'],
#              'kindness': ['2'],
#              'action': ['2'],
#              'serious': ['2', '3'],
#              'qualities': ['1', '2', '3'],
#              'irritability': ['2'],
#              'allow': ['1', '3'],
#              'chapters': ['1'],
#              'purchaser': ['2'],
#              '000': ['3'],
#              'lovable': ['2'],
#              'USE': ['3'],
#              'devoted': ['1'],
#              'infringement': ['3'],
#              'temptation': ['1'],
#              'imperceptible': ['2'],
#              'letters': ['1', '2', '3'],
#              'Concerning': ['2'],
#              'shop': ['1', '2'],
#              'share': ['3'],
#              'Mulready': ['3'],
#              'successful': ['1', '3'],
#              'spoils': ['3'],
#              'Infant': ['2'],
#              'much': ['1', '2', '3'],
#              'permanent': ['3'],
#              'seeming': ['2'],
#              'derived': ['3'],
#              'exhibited': ['1', '2', '3'],
#              'Charles': ['2', '3'],
#              'departs': ['3'],
#              'drunkards': ['2'],
#              'restored': ['1'],
#              'essay': ['1'],
#              'title': ['1', '3'],
#              'together': ['1', '2'],
#              'sir': ['1', '2', '3'],
#              'Dame': ['1'],
#              'charge': ['1', '3'],
#              'tired': ['1', '2'],
#              'Revenue': ['3'],
#              'difficulty': ['1'],
#              'Duchess': ['1'],
#              'visits': ['2'],
#              'eyebrows': ['1'],
#              'Mansion': ['2'],
#              'old': ['1', '2', '3'],
#              'banks': ['2'],
#              'bombastic': ['2'],
#              'dissimilarity': ['2'],
#              'boulevards': ['3'],
#              'sun': ['1', '3'],
#              'bookseller': ['1'],
#              'tomb': ['1'],
#              'friends': ['2'],
#              'addresses': ['3'],
#              'introduced': ['1'],
#              'States': ['1', '3'],
#              'limelight': ['3'],
#              'installed': ['1'],
#              'Palleri': ['1'],
#              '15': ['1'],
#              'wonder': ['2'],
#              'provision': ['3'],
#              'looks': ['3'],
#              'Georges': ['1'],
#              '32': ['2'],
#              'food': ['2'],
#              'lessons': ['1', '2'],
#              'inflated': ['2'],
#              'PGLAF': ['3'],
#              'theatre': ['3'],
#              'differences': ['2'],
#              'tragedy': ['2'],
#              'consists': ['3'],
#              'dignity': ['1'],
#              'vet': ['1', '2'],
#              'pretended': ['1'],
#              'ological': ['1', '3'],
#              'comely': ['3'],
#              'impetuous': ['1'],
#              'powers': ['1'],
#              'builder': ['1'],
#              'prices': ['1'],
#              'knees': ['1', '2'],
#              'HAROLD': ['1'],
#              'une': ['2'],
#              'hear': ['3'],
#              'least': ['3'],
#              'figure': ['1', '2', '3'],
#              'exporting': ['3'],
#              'Axel': ['3'],
#              'damaged': ['3'],
#              'disreputable': ['2'],
#              'overwhelmed': ['3'],
#              'provide': ['1', '3'],
#              'one': ['1', '2', '3'],
#              'convinces': ['1'],
#              'water': ['3'],
#              'Century': ['3'],
#              'Stone': ['3'],
#              'Robert': ['2'],
#              'artists': ['1', '2', '3'],
#              'palaces': ['2'],
#              'ROBESPIERRE': ['3'],
#              'passionately': ['2'],
#              'faults': ['2'],
#              'Compi': ['3'],
#              'N': ['3'],
#              'rank': ['1', '2'],
#              'preached': ['3'],
#              'superintend': ['1'],
#              'short': ['3'],
#              'cle': ['3'],
#              'thinking': ['2'],
#              'devout': ['1'],
#              'early': ['1', '2', '3'],
#              'human': ['2'],
#              'costly': ['2'],
#              'tedious': ['3'],
#              'Cass': ['1', '3'],
#              'reads': ['1'],
#              'blow': ['2'],
#              'factory': ['1'],
#              'hostility': ['1'],
#              'corrupt': ['3'],
#              'softened': ['2'],
#              'copying': ['1', '3'],
#              'enabled': ['1'],
#              'freed': ['2'],
#              'Section': ['3'],
#              'cover': ['2'],
#              'boys': ['1', '2'],
#              'discuss': ['1'],
#              'Quarter': ['2'],
#              'stored': ['3'],
#              'city': ['2', '3'],
#              '6221541': ['3'],
#              'accessed': ['3'],
#              'earrings': ['2'],
#              'life': ['1', '2', '3'],
#              'captivate': ['3'],
#              'country': ['1', '2', '3'],
#              'encouraged': ['1'],
#              'website': ['3'],
#              'French': ['1', '2', '3'],
#              'manner': ['1', '2', '3'],
#              'INDIRECT': ['3'],
#              'fellow': ['3'],
#              'go': ['1', '2', '3'],
#              'errors': ['3'],
#              'fared': ['1'],
#              'washing': ['3'],
#              'defect': ['3'],
#              '4': ['1', '2', '3'],
#              'handsome': ['3'],
#              'destroyed': ['2'],
#              'magistrates': ['2'],
#              'opportunity': ['3'],
#              'barren': ['1', '3'],
#              'literary': ['3'],
#              'charming': ['1', '2', '3'],
#              'confirmation': ['3'],
#              'taken': ['1'],
#              'Jet': ['1', '3'],
#              'individual': ['3'],
#              '20': ['1', '3'],
#              'Dijon': ['3'],
#              'illustrious': ['1'],
#              'various': ['2', '3'],
#              'anything': ['3'],
#              'nineteenth': ['3'],
#              'vein': ['2'],
#              'conduct': ['2'],
#              'Three': ['2', '3'],
#              'Personal': ['1'],
#              'mind': ['2'],
#              'ability': ['1'],
#              'appeal': ['1', '2'],
#              'chivalrous': ['1', '2'],
#              'robe': ['1'],
#              'merits': ['2'],
#              'commendation': ['1'],
#              'UNITED': ['3'],
#              'Levasseur': ['1'],
#              'smart': ['1'],
#              'light': ['1', '2', '3'],
#              'issued': ['3'],
#              'p': ['3'],
#              'carry': ['3'],
#              'Bell': ['1'],
#              'minds': ['2', '3'],
#              'process': ['2'],
#              'Truly': ['3'],
#              'wasted': ['1'],
#              'merit': ['1', '2'],
#              'princes': ['1'],
#              'homilies': ['2'],
#              'feeling': ['3'],
#              'BREACH': ['3'],
#              'industry': ['1', '2'],
#              'affected': ['2'],
#              'creation': ['3'],
#              'convert': ['3'],
#              'apparent': ['1', '3'],
#              'virus': ['3'],
#              'dog': ['1', '2'],
#              'cajoleries': ['2'],
#              'picturesque': ['1', '3'],
#              'Apple': ['3'],
#              'accumulate': ['2'],
#              'unsolicited': ['3'],
#              'sometimes': ['2', '3'],
#              'books': ['1', '2'],
#              'strayed': ['1'],
#              'hind': ['2'],
#              'helped': ['1'],
#              'fees': ['3'],
#              'troubled': ['3'],
#              'seat': ['2'],
#              'vient': ['3'],
#              'Strogonoff': ['2', '3'],
#              '49': ['3'],
#              'Offrande': ['3'],
#              'Yarborough': ['3'],
#              'notifies': ['3'],
#              'ideals': ['1'],
#              'research': ['3'],
#              'official': ['3'],
#              'stage': ['2', '3'],
#              '7': ['1', '3'],
#              'downcast': ['1', '2', '3'],
#              'Biographie': ['2'],
#              'Arthur': ['2'],
#              'reprochant': ['1'],
#              'hastens': ['2'],
#              'Nantes': ['3'],
#              'degenerated': ['3'],
#              'month': ['2'],
#              'employment': ['3'],
#              'attach': ['2'],
#              'kiss': ['3'],
#              'achieved': ['1', '2'],
#              'palace': ['1'],
#              'give': ['1', '2', '3'],
#              'shed': ['2'],
#              'reaped': ['3'],
#              'downright': ['2'],
#              'fear': ['2'],
#              'invoking': ['1'],
#              'exercising': ['1'],
#              'witness': ['2'],
#              'ought': ['1', '2'],
#              'talk': ['2'],
#              'shoulders': ['2'],
#              'widest': ['3'],
#              'Language': ['1'],
#              'say': ['1', '2'],
#              'candour': ['2'],
#              'times': ['2', '3'],
#              'classes': ['2'],
#              'giving': ['2', '3'],
#              'blurted': ['1'],
#              'ascertained': ['2'],
#              'burning': ['3'],
#              'inasmuch': ['1'],
#              'alone': ['1', '2', '3'],
#              'pearly': ['2'],
#              'man': ['1', '2', '3'],
#              'school': ['1', '2', '3'],
#              'August': ['1'],
#              'Mistaking': ['1'],
#              'impressive': ['2'],
#              'main': ['2', '3'],
#              'gin': ['2'],
#              'congratulate': ['2'],
#              'ever': ['1', '2'],
#              'delirium': ['1'],
#              'imperfection': ['2'],
#              'letter': ['1', '2', '3'],
#              'farm': ['1', '3'],
#              'description': ['3'],
#              'yoke': ['3'],
#              'rooms': ['2'],
#              'god': ['1'],
#              'c': ['3'],
#              'confidence': ['1'],
#              'advanced': ['1'],
#              'states': ['1', '3'],
#              'walking': ['2'],
#              'injustices': ['1'],
#              'novelty': ['1', '2'],
#              'face': ['1', '2', '3'],
#              'wedding': ['2'],
#              'freak': ['2'],
#              'introduction': ['1'],
#              'Laundress': ['1', '3'],
#              'servants': ['1'],
#              'suggesting': ['2'],
#              'il': ['2'],
#              'Also': ['2'],
#              'real': ['1', '2'],
#              'precarious': ['1'],
#              'sentimental': ['2', '3'],
#              'tops': ['2'],
#              'quays': ['3'],
#              'processes': ['2'],
#              'proofread': ['3'],
#              'Fille': ['2', '3'],
#              'pitcher': ['1', '3'],
#              'crossing': ['2'],
#              'modern': ['2', '3'],
#              'housekeeping': ['2'],
#              'LICENSE': ['3'],
#              'cause': ['1', '2', '3'],
#              'perfidious': ['1'],
#              'distinction': ['2'],
#              'explanation': ['3'],
#              'died': ['1', '2'],
#              'Mission': ['3'],
#              'represented': ['1', '2', '3'],
#              'considered': ['1'],
#              'bookshop': ['1'],
#              'risk': ['2'],
#              'heart': ['1', '2'],
#              'hope': ['1', '3'],
#              'perhaps': ['3'],
#              'sublimation': ['3'],
#              'Marseille': ['3'],
#              'ceased': ['1', '2'],
#              'copied': ['1', '3'],
#              'dans': ['1'],
#              'One': ['1', '2'],
#              'reports': ['3'],
#              '13': ['1'],
#              'verge': ['2'],
#              'yet': ['1', '2', '3'],
#              'cemetery': ['1'],
#              'dish': ['3'],
#              'Sections': ['3'],
#              'gain': ['3'],
#              'apart': ['2'],
#              'demurrer': ['2'],
#              'Arcade': ['3'],
#              'doors': ['1'],
#              'cried': ['1'],
#              'agreement': ['3'],
#              'commencing': ['1'],
#              'remarkable': ['3'],
#              '1874': ['2'],
#              'provincial': ['1'],
#              'refinements': ['3'],
#              'playing': ['3'],
#              'Works': ['1'],
#              'chamberlain': ['1'],
#              'resplendent': ['1'],
#              'come': ['1', '2', '3'],
#              'God': ['1'],
#              'charms': ['1', '2'],
#              'forest': ['3'],
#              'hundreds': ['3'],
#              'laid': ['3'],
#              'poor': ['1', '2', '3'],
#              'dashing': ['1'],
#              'wishes': ['1'],
#              'touching': ['2'],
#              'ten': ['1'],
#              'broke': ['2', '3'],
#              'comprehensive': ['1'],
#              'Une': ['2'],
#              'dawn': ['2'],
#              'INCLUDING': ['3'],
#              'last': ['1', '2', '3'],
#              'coup': ['2'],
#              'redistributing': ['3'],
#              'vengeance': ['1'],
#              'CONSEQUENTIAL': ['3'],
#              'present': ['1', '2'],
#              'reaching': ['3'],
#              'study': ['1', '2', '3'],
#              'needed': ['1'],
#              'illustration': ['2'],
#              'whole': ['1', '2', '3'],
#              'extraordinary': ['1'],
#              'morals': ['2'],
#              'maticien': ['3'],
#              'lieu': ['3'],
#              'artificial': ['2'],
#              'bread': ['2', '3'],
#              'copy': ['1', '3'],
#              'sunk': ['2'],
#              'page': ['3'],
#              'Homme': ['2'],
#              'social': ['2'],
#              'treasured': ['2'],
#              'enough': ['1', '2', '3'],
#              'License': ['1', '3'],
#              'indicated': ['2'],
#              'cease': ['2', '3'],
#              'circle': ['1'],
#              'later': ['1', '3'],
#              'Savoy': ['3'],
#              'mistaking': ['1'],
#              'Barthelemy': ['1'],
#              'song': ['2'],
#              'proprietary': ['3'],
#              'feels': ['2'],
#              'ROMANCE': ['1'],
#              'occupies': ['1'],
#              'bourgeois': ['2'],
#              'beset': ['1'],
#              'washerwomen': ['2', '3'],
#              'sits': ['3'],
#              'host': ['2'],
#              'splendour': ['1'],
#              '1732': ['1'],
#              'rosy': ['1', '2', '3'],
#              'C': ['3'],
#              'Napoleon': ['1'],
#              'Terms': ['3'],
#              'end': ['1', '2', '3'],
#              'delicious': ['1'],
#              'closed': ['1', '2', '3'],
#              'teach': ['2'],
#              'clear': ['2'],
#              'waistcoat': ['3'],
#              'round': ['1', '2'],
#              'Lesser': ['3'],
#              'Artistes': ['3'],
#              'classicism': ['3'],
#              'Peintres': ['3'],
#              'approach': ['3'],
#              'longer': ['1', '2'],
#              'winsome': ['3'],
#              'Whistler': ['2'],
#              'verdigris': ['2'],
#              'dreary': ['1'],
#              'hitherto': ['1', '3'],
#              'ease': ['1'],
#              'surprised': ['1', '2'],
#              'ran': ['1'],
#              'warranties': ['3'],
#              'completed': ['1'],
#              'twenty': ['1', '2', '3'],
#              'posy': ['2'],
#              'skill': ['1', '3'],
#              'parle': ['2'],
#              'linked': ['3'],
#              'FRANCE': ['3'],
#              'James': ['1'],
#              'wife': ['1', '2'],
#              '56': ['3'],
#              'Service': ['3'],
#              'Mariage': ['1', '3'],
#              'plates': ['1'],
#              'Tendre': ['3'],
#              'pretty': ['1', '2', '3'],
#              'Cook': ['3'],
#              'solitude': ['1', '3'],
#              'BESAN': ['3'],
#              'therefore': ['1', '2', '3'],
#              'refuse': ['1'],
#              'kept': ['1'],
#              'v': ['1'],
#              'thick': ['1', '2'],
#              'injustice': ['1'],
#              'treated': ['1', '2'],
#              'Rousseau': ['3'],
#              'Boucher': ['2', '3'],
#              'charitable': ['3'],
#              'heed': ['1'],
#              'International': ['3'],
#              'Duc': ['1'],
#              'LAUNDRESS': ['2'],
#              'merited': ['1'],
#              'studio': ['1'],
#              'satisfaction': ['1'],
#              'DISTRIBUTOR': ['3'],
#              'Draped': ['3'],
#              'Donaldson': ['3'],
#              'smote': ['1'],
#              'COLLECTION': ['3'],
#              'sublime': ['1'],
#              'pleure': ['2'],
#              'Whose': ['1'],
#              'academic': ['1'],
#              'standards': ['2'],
#              'native': ['3'],
#              'Brown': ['2', '3'],
#              'clearly': ['3'],
#              'communicate': ['2'],
#              'sympathetic': ['2'],
#              'reaction': ['3'],
#              'armour': ['1'],
#              'obtrusive': ['2'],
#              '34': ['2'],
#              'heap': ['2'],
#              'gloomy': ['1'],
#              'went': ['1', '2', '3'],
#              'clock': ['3'],
#              'intense': ['3'],
#              'animated': ['2'],
#              'bores': ['3'],
#              'precisely': ['3'],
#              'step': ['2'],
#              'evidence': ['2'],
#              'eldest': ['1'],
#              'beautifully': ['1'],
#              'certainty': ['1'],
#              'exclaimed': ['1', '2'],
#              'recent': ['2'],
#              'stormers': ['2'],
#              'preacher': ['2'],
#              'attributed': ['1', '3'],
#              'within': ['3'],
#              'crime': ['2'],
#              'seeing': ['1', '2', '3'],
#              'gave': ['1', '2'],
#              'rouge': ['2'],
#              'forehead': ['2'],
#              'Fontainebleau': ['3'],
#              'Este': ['1'],
#              'loving': ['1'],
#              'appearing': ['3'],
#              'exclusion': ['3'],
#              'peculiarly': ['1'],
#              'version': ['3'],
#              'exhibit': ['1'],
#              'generally': ['2'],
#              'foolish': ['2'],
#              'PUNITIVE': ['3'],
#              '596': ['3'],
#              'Zola': ['2'],
#              'PERSONAL': ['2'],
#              'houses': ['1'],
#              'fourteen': ['2'],
#              'prominently': ['2', '3'],
#              'assume': ['3'],
#              'push': ['1'],
#              'paper': ['1', '2', '3'],
#              '1885': ['3'],
#              'Alexander': ['2', '3'],
#              'se': ['1', '3'],
#              'teaching': ['2'],
#              'ses': ['1', '2', '3'],
#              'effective': ['3'],
#              'Almost': ['1'],
#              'began': ['1', '2'],
#              'Jointes': ['3'],
#              'unsatisfactory': ['2'],
#              'speaks': ['1'],
#              'Lowther': ['3'],
#              '90': ['3'],
#              'particular': ['3'],
#              'reveal': ['2'],
#              'instability': ['1'],
#              'demonstrated': ['2'],
#              'sisters': ['3'],
#              'returned': ['1', '2'],
#              'barbaric': ['3'],
#              'attention': ['1', '2'],
#              'utter': ['2'],
#              'day': ['1', '2', '3'],
#              'colours': ['2', '3'],
#              'Jar': ['3'],
#              'house': ['1', '2', '3'],
#              'Mal': ['1', '3'],
#              'seventy': ['1'],
#              'sweet': ['2', '3'],
#              'Poverty': ['1'],
#              'reward': ['3'],
#              'Marquis': ['2', '3'],
#              'perished': ['3'],
#              'answered': ['2'],
#              'PG': ['3'],
#              'rules': ['3'],
#              'Live': ['1'],
#              'pleasantries': ['2'],
#              'Maclise': ['2', '3'],
#              'array': ['3'],
#              'stools': ['1'],
#              'wash': ['2', '3'],
#              'fee': ['3'],
#              'viii': ['1'],
#              'uniform': ['3'],
#              'Martin': ['3'],
#              '1821': ['3'],
#              'mother': ['1', '2', '3'],
#              'pictorial': ['2'],
#              'suspicion': ['1', '2'],
#              'House': ['2', '3'],
#              'departure': ['3'],
#              'brusque': ['2'],
#              'breaking': ['3'],
#              'complete': ['3'],
#              'market': ['2', '3'],
#              'Troyes': ['3'],
#              'meadow': ['3'],
#              'Lake': ['3'],
#              'motive': ['2'],
#              'lit': ['1', '2'],
#              'hour': ['1', '2', '3'],
#              'compensated': ['2'],
#              'purpose': ['3'],
#              'Donations': ['3'],
#              'following': ['3'],
#              'dust': ['1'],
#              'GUILDFORD': ['3'],
#              'conventions': ['1', '2', '3'],
#              'advocate': ['3'],
#              'loose': ['3'],
#              'part': ['1', '2', '3'],
#              'fancy': ['3'],
#              'three': ['1', '2'],
#              'presentment': ['1', '3'],
#              'death': ['1'],
#              'distributed': ['3'],
#              'willingness': ['1'],
#              'another': ['1', '2', '3'],
#              'amidst': ['1', '3'],
#              'hide': ['2'],
#              'RIGHT': ['3'],
#              'journals': ['1', '3'],
#              'epoch': ['1'],
#              'finished': ['1', '2', '3'],
#              'journalist': ['2'],
#              'filled': ['1'],
#              'persuasions': ['1'],
#              'primarily': ['2'],
#              'dainty': ['3'],
#              'computer': ['3'],
#              '1895': ['3'],
#              'stretches': ['2'],
#              'Robespierre': ['1', '3'],
#              'esteem': ['2'],
#              'amenity': ['2'],
#              'thousand': ['1'],
#              'well': ['2', '3'],
#              'accord': ['1', '3'],
#              'demeanour': ['1'],
#              'door': ['2'],
#              'draws': ['2'],
#              'virtue': ['3'],
#              'bodices': ['2'],
#              'away': ['1', '2', '3'],
#              'described': ['1', '3'],
#              'Engravings': ['1'],
#              'directly': ['3'],
#              'abuse': ['2'],
#              'adopted': ['2'],
#              'rested': ['1'],
#              'danger': ['2'],
#              'keeping': ['3'],
#              'vain': ['2'],
#              'deliberate': ['2'],
#              'constitution': ['1', '2'],
#              '11': ['1'],
#              'neglect': ['1', '2'],
#              '43': ['2'],
#              'finds': ['2'],
#              'connoisseur': ['1'],
#              'obscure': ['1'],
#              'sold': ['2', '3'],
#              'bourgeoise': ['3'],
#              'Solomon': ['1'],
#              'Hundreds': ['1'],
#              'Anne': ['1'],
#              'Twelve': ['3'],
#              'principal': ['1', '2'],
#              'pastorals': ['1', '3'],
#              'already': ['1', '2', '3'],
#              'genius': ['1', '2', '3'],
#              'maledictions': ['1'],
#              'indicates': ['2', '3'],
#              'dilettanti': ['1'],
#              'fresh': ['2'],
#              'R': ['2'],
#              'says': ['1', '2', '3'],
#              'profoundly': ['2'],
#              'men': ['1', '2', '3'],
#              'Mains': ['3'],
#              'gauze': ['2', '3'],
#              'authority': ['1', '3'],
#              'www': ['1', '3'],
#              'domestic': ['2', '3'],
#              '27': ['2'],
#              'sister': ['2', '3'],
#              'Thirty': ['2'],
#              'pleasure': ['1', '2', '3'],
#              'excellence': ['1', '2'],
#              'harmless': ['3'],
#              'knew': ['1', '2'],
#              'livelihood': ['1'],
#              'charm': ['1', '2', '3'],
#              'easel': ['1'],
#              'absolutely': ['3'],
#              'await': ['1'],
#              'quelle': ['2'],
#              'pointillists': ['2'],
#              'lower': ['2'],
#              'Kiss': ['1', '3'],
#              'second': ['1', '2', '3'],
#              'historique': ['2'],
#              'computers': ['3'],
#              'indeed': ['1', '2', '3'],
#              'providing': ['3'],
#              'attracted': ['1', '2'],
#              'Duke': ['1', '3'],
#              'stammer': ['1'],
#              'employees': ['3'],
#              'production': ['3'],
#              'arched': ['1'],
#              'somewhat': ['2'],
#              'belong': ['1', '2'],
#              'relate': ['3'],
#              'engraved': ['3'],
#              'agree': ['3'],
#              'strong': ['1', '2'],
#              'asked': ['1', '2'],
#              'absurdities': ['1'],
#              'enthusiastic': ['1', '2'],
#              'ideas': ['1', '2', '3'],
#              'directed': ['2'],
#              'fall': ['2'],
#              'Barth': ['1'],
#              'Like': ['2', '3'],
#              'simplicity': ['2', '3'],
#              'often': ['1', '2', '3'],
#              'slow': ['2'],
#              'bridegroom': ['3'],
#              'toys': ['3'],
#              'request': ['3'],
#              'labour': ['3'],
#              'recognise': ['1'],
#              'based': ['3'],
#              'Fabricius': ['3'],
#              'tints': ['2'],
#              'shirt': ['1'],
#              'Ducreux': ['3'],
#              'sketch': ['2', '3'],
#              'Reginald': ['3'],
#              'hung': ['1', '3'],
#              'strain': ['3'],
#              'obtaining': ['3'],
#              'Muther': ['2', '3'],
#              'father': ['1', '2', '3'],
#              'phrase': ['2', '3'],
#              'believe': ['1'],
#              'voluptuousness': ['2'],
#              'Eighteenth': ['3'],
#              'sent': ['1', '3'],
#              'Nothing': ['2'],
#              'keep': ['3'],
#              'duties': ['2'],
#              'forced': ['1'],
#              'threats': ['1'],
#              'change': ['1', '3'],
#              'excellent': ['1', '3'],
#              'like': ['1', '2', '3'],
#              'profits': ['3'],
#              'steps': ['3'],
#              'De': ['1', '2', '3'],
#              'searching': ['2'],
#              'measure': ['3'],
#              'Servi': ['3'],
#              'Carlyle': ['3'],
#              'Bible': ['1', '2'],
#              'promised': ['1', '2'],
#              'moved': ['2'],
#              'member': ['1', '3'],
#              ...})

# %%
doc_coll = list(document)

# %%
df = pd.DataFrame(list(document.items()), columns = ['words','Posting List'])
df
# Out:
#            words Posting List
# 0          story    [1, 2, 3]
# 1        pleased          [2]
# 2        nestles          [2]
# 3        fifteen          [3]
# 4      furniture          [3]
# ...          ...          ...
# 3635  volunteers          [3]
# 3636     whether    [1, 2, 3]
# 3637       homes          [2]
# 3638        Upon          [2]
# 3639     Millais       [2, 3]
#
# [3640 rows x 2 columns]

# %%
map_dict = {'1': 'Greuze1', '2': 'Greuze2', '3': 'Greuze3'}

# %%
# Function for applying boolean operators to the inverted index
def inverted_index(query):
  for word_token in query.split():
    if word_token == 'and':
      query = query.replace(word_token, '&')
    elif word_token == 'or':
      query = query.replace(word_token, '|')
    elif word_token == 'not':
      query = query.replace(word_token, "{'1','2','3'}-")
  for word_token in query.split():
    if word_token.isalpha():
      query = query.replace(word_token, repr(set(document[word_token])))
  return query

# %% [markdown]
# query 1

# %%
query1 = 'fear and happy'
exp1 = inverted_index(query1)
exp1
# Out:
# "{'2'} & {'1', '2'}"

# %%
final_result1 = eval(exp1)
final_result1
# Out:
# {'2'}

# %% [markdown]
# From the result of Query 1, we can infer that the document 1 which corresponds to the text 'Greuze2', is the only text that contains both the words 'fear' and 'happy'.

# %% [markdown]
# Query 2

# %%
query2 = 'fear and not happy'
exp2 = inverted_index(query2)
exp2
# Out:
# "{'2'} & {'1','2','3'}- {'1', '2'}"

# %%
final_result2 = eval(exp2)
final_result2
# Out:
# set()

# %%
for i in final_result2:
  print(map_dict[i])

# %% [markdown]
# Query 3

# %%
query3 = 'fear or happy'
exp3 = inverted_index(query3)
exp3
# Out:
# "{'2'} | {'1', '2'}"

# %%
final_result3 = eval(exp3)
final_result3
# Out:
# {'1', '2'}

# %%
for i in final_result3:
  print(map_dict[i])
# Out:
# Greuze1
# Greuze2

# %% [markdown]
# From the result of Query 3, we can infer that the documents 1, and 2, which corresponds to the texts 'Greuze1', 'Greuze2' respectively, contains either the word 'fear' or 'happy'

# %% [markdown]
# Query 4

# %%
query4 = 'not fear or not happy'
exp4 = inverted_index(query4)
exp4
# Out:
# "{'1','2','3'}- {'2'} | {'1','2','3'}- {'1', '2'}"

# %%
final_result4 = eval(exp4)
final_result4
# Out:
# {'1', '3'}

# %%
for word_token in final_result4:
  print(map_dict[word_token])
# Out:
# Greuze1
# Greuze3

# %% [markdown]
# From the result of Query 4, we can infer that the documents 1 and 3 which corresponds to the texts 'Greuze1' and 'Greuze3' respectively, either do not contains the word 'fear' or do not contain the word 'broke'

# %% [markdown]
# Query 5

# %%
query5="fear or not happy"
exp5=inverted_index(query5)
exp5
# Out:
# "{'2'} | {'1','2','3'}- {'1', '2'}"

# %%
final_result5=eval(exp5)
final_result5
# Out:
# {'2', '3'}

# %%
for word_token in final_result5:
  print(map_dict[word_token])
# Out:
# Greuze3
# Greuze2

# %% [markdown]
# From the result of query5, it is clear that the docs 2 and 3 corresponding to the texts 'Greuze2' and 'Greuze3', respectively either contains the word 'fear' or donot contain the word 'happy'.
